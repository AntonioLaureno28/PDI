# %%
import numpy as np
import matplotlib.pyplot as plt 
import cv2

# %%
# Carregando a imagem com o OpenCV
imagem  = cv2.imread('images/hubble.jpg')
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

image.shape
# Out:
# (528, 485)

# %% [markdown]
# ## Aplicando o Filtro de média

# %%
imagem_corrigida = cv2.blur(image, (15, 15))

# %%
# Plotando o resultado

plt.figure(figsize=(10,8))
plt.imshow(imagem_corrigida, 'gray')

# %% [markdown]
# ## Aplicando o a limiarização

# %%
t = 65
binary_mask = imagem_corrigida > t

plt.figure(figsize=(10,8))
plt.imshow(binary_mask, cmap='gray')

# %% [markdown]
# ## Plotando as imagens

# %%
plt.figure(figsize=(15,15))

plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.title('Imagem original')

plt.subplot(1, 3, 2)
plt.imshow(imagem_corrigida, cmap='gray')
plt.title('Imagem filtrada com filtro de média (15x15)')


plt.subplot(1, 3, 3)
plt.imshow(binary_mask, cmap='gray')
plt.title('Imagem filtrada com limiarização')
# Out:
# Text(0.5, 1.0, 'Imagem filtrada com limiarização')
